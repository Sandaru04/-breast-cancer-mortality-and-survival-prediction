# %% [markdown]
# # Author : Sandaru Malshan
# # Peer Reviewer :[]
# # Date of peer Review:[]

# %%
# installing the data manipulations library
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Load the Dataset

# %%
import pandas as pd
print("===========================================================")
print("Load the Classification dataset (from Notebook 1)")
print("===========================================================")

df = pd.read_csv('/content/classification_dataset.csv')

# Display basic info
df.head()
# Out:
# ===========================================================
# Load the Classification dataset (from Notebook 1)
# ===========================================================
#     Age  Sex  T_Stage  N_Stage  6th_Stage  Differentiated  Grade  A_Stage  \
# 0  68.0    1        0        0          0               1      3        1
# 1  50.0    1        1        1          2               0      2        1
# 2  58.0    1        2        2          4               0      2        1
# 3  58.0    1        0        0          0               1      3        1
# 4  47.0    1        1        0          1               1      3        1
#
#    Tumor_Size  Estrogen_Status  Progesterone_Status  Regional_Node_Examined  \
# 0         4.0                1                    1                    24.0
# 1        35.0                1                    1                    14.0
# 2        63.0                1                    1                    14.0
# 3        18.0                1                    1                     2.0
# 4        41.0                1                    1                     3.0
#
#    Reginol_Node_Positive  Mortality_Status
# 0                      1                 0
# 1                      5                 0
# 2                      7                 0
# 3                      1                 0
# 4                      1                 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3487 entries, 0 to 3486
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     3487 non-null   float64
#  1   Sex                     3487 non-null   int64
#  2   T_Stage                 3487 non-null   int64
#  3   N_Stage                 3487 non-null   int64
#  4   6th_Stage               3487 non-null   int64
#  5   Differentiated          3487 non-null   int64
#  6   Grade                   3487 non-null   int64
#  7   A_Stage                 3487 non-null   int64
#  8   Tumor_Size              3487 non-null   float64
#  9   Estrogen_Status         3487 non-null   int64
#  10  Progesterone_Status     3487 non-null   int64
#  11  Regional_Node_Examined  3487 non-null   float64
#  12  Reginol_Node_Positive   3487 non-null   int64
#  13  Mortality_Status        3487 non-null   int64
# dtypes: float64(3), int64(11)
# memory usage: 381.5 KB

# %%
df.describe()
# Out:
#                Age          Sex      T_Stage      N_Stage    6th_Stage  \
# count  3487.000000  3487.000000  3487.000000  3487.000000  3487.000000
# mean     54.018354     0.994838     0.679094     0.297964     1.043590
# std       8.910675     0.071672     0.693364     0.546048     1.035704
# min      30.000000     0.000000     0.000000     0.000000     0.000000
# 25%      47.000000     1.000000     0.000000     0.000000     0.000000
# 50%      54.000000     1.000000     1.000000     0.000000     1.000000
# 75%      61.000000     1.000000     1.000000     1.000000     2.000000
# max      69.000000     1.000000     3.000000     2.000000     4.000000
#
#        Differentiated        Grade      A_Stage   Tumor_Size  Estrogen_Status  \
# count     3487.000000  3487.000000  3487.000000  3487.000000      3487.000000
# mean         0.690278     2.128190     0.988242    26.352165         0.942931
# std          1.032115     0.633203     0.107810    14.752010         0.232008
# min          0.000000     1.000000     0.000000     1.000000         0.000000
# 25%          0.000000     2.000000     1.000000    15.000000         1.000000
# 50%          0.000000     2.000000     1.000000    23.000000         1.000000
# 75%          1.000000     3.000000     1.000000    34.000000         1.000000
# max          3.000000     4.000000     1.000000    70.000000         1.000000
#
#        Progesterone_Status  Regional_Node_Examined  Reginol_Node_Positive  \
# count          3487.000000             3487.000000            3487.000000
# mean              0.836249               13.284772               2.883854
# std               0.370103                7.132992               2.576760
# min               0.000000                1.000000               1.000000
# 25%               1.000000                8.000000               1.000000
# 50%               1.000000               13.000000               2.000000
# 75%               1.000000               18.000000               4.000000
# max               1.000000               35.000000              12.000000
#
#        Mortality_Status
# count       3487.000000
# mean           0.125609
# std            0.331456
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %% [markdown]
# ##Selecting Feature

# %%
# Define target and features
X = df.drop("Mortality_Status", axis=1)
y = df["Mortality_Status"]

print("==== x data ====")
print(X.head())
print("\n==== y data ====\n")
print(y.head())
# Out:
# ==== x data ====
#     Age  Sex  T_Stage  N_Stage  6th_Stage  Differentiated  Grade  A_Stage  \
# 0  68.0    1        0        0          0               1      3        1
# 1  50.0    1        1        1          2               0      2        1
# 2  58.0    1        2        2          4               0      2        1
# 3  58.0    1        0        0          0               1      3        1
# 4  47.0    1        1        0          1               1      3        1
#
#    Tumor_Size  Estrogen_Status  Progesterone_Status  Regional_Node_Examined  \
# 0         4.0                1                    1                    24.0
# 1        35.0                1                    1                    14.0
# 2        63.0                1                    1                    14.0
# 3        18.0                1                    1                     2.0
# 4        41.0                1                    1                     3.0
#
#    Reginol_Node_Positive
# 0                      1
# 1                      5
# 2                      7
# 3                      1
# 4                      1
#
# ==== y data ====
#
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Mortality_Status, dtype: int64

# %% [markdown]
# ### Divide data set training and testing

# %%
from sklearn.model_selection import train_test_split

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# ### Data Standardization

# %%
from sklearn.preprocessing import StandardScaler

# Feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ## Build Base Learners & Ensemble

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# Base learners
lr = LogisticRegression(max_iter=1000)
nb = GaussianNB()

# Voting Ensemble
ensemble = VotingClassifier(estimators=[('lr', lr),('nb', nb)], voting='soft')

ensemble.fit(X_train_scaled, y_train)
y_pred_ensemble = ensemble.predict(X_test_scaled)

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt

print(confusion_matrix(y_test, y_pred_ensemble))
print(classification_report(y_test, y_pred_ensemble))

# AUC-ROC
y_proba = ensemble.predict_proba(X_test_scaled)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_proba)
auc = roc_auc_score(y_test, y_proba)

plt.plot(fpr, tpr, label=f'Ensemble AUC = {auc:.2f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Ensemble ROC Curve')
plt.legend()
plt.show()
# Out:
# [[832  83]
#  [100  32]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       915
#            1       0.28      0.24      0.26       132
#
#     accuracy                           0.83      1047
#    macro avg       0.59      0.58      0.58      1047
# weighted avg       0.82      0.83      0.82      1047

# %% [markdown]
# # Part B: Decision Tree Regression for Survival_Months

# %% [markdown]
# ## Load Regression Dataset

# %%
import pandas as pd
print("===========================================================")
print("Load the Regression dataset (from Notebook 1)")
print("===========================================================")

data_frame = pd.read_csv('/content/regression_dataset.csv')

# Display basic info
data_frame.head()
# Out:
# ===========================================================
# Load the Regression dataset (from Notebook 1)
# ===========================================================
#     Age  Tumor_Size  Regional_Node_Examined  Reginol_Node_Positive  \
# 0  40.0        30.0                     9.0                      1
# 1  68.0        13.0                     9.0                      1
# 2  57.0        70.0                    12.0                     12
# 3  42.0         9.0                    15.0                      2
# 4  67.0        13.0                    16.0                      3
#
#    Survival_Months
# 0               14
# 1               64
# 2               42
# 3               39
# 4               60

# %% [markdown]
# ### Selecting Feature

# %%
# Define target and features
X = data_frame.drop("Survival_Months", axis=1)
y = data_frame["Survival_Months"]

print("==== x data ====")
print(X.head())
print("\n==== y data ====\n")
print(y.head())
# Out:
# ==== x data ====
#     Age  Tumor_Size  Regional_Node_Examined  Reginol_Node_Positive
# 0  40.0        30.0                     9.0                      1
# 1  68.0        13.0                     9.0                      1
# 2  57.0        70.0                    12.0                     12
# 3  42.0         9.0                    15.0                      2
# 4  67.0        13.0                    16.0                      3
#
# ==== y data ====
#
# 0    14
# 1    64
# 2    42
# 3    39
# 4    60
# Name: Survival_Months, dtype: int64

# %% [markdown]
# ### Divide data set training and testing

# %%
from sklearn.model_selection import train_test_split

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Import and Fit Decision Tree Regressors

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
import matplotlib.pyplot as plt

# Fully grown tree (DT-1)
dt1 = DecisionTreeRegressor(random_state=42)
dt1.fit(X_train, y_train)

# Pruned tree (DT-2)
dt2 = DecisionTreeRegressor(max_depth=4, random_state=42)
dt2.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, random_state=42)

# %% [markdown]
# ## Visualize the Trees

# %%
# Visualize DT-1
plt.figure(figsize=(20, 10))
plot_tree(dt1, filled=True, feature_names=X.columns)
plt.title("Fully Grown DT (DT-1)")
plt.show()

# Visualize DT-2
plt.figure(figsize=(20, 10))
plot_tree(dt2, filled=True, feature_names=X.columns)
plt.title("Pruned DT (DT-2)")
plt.show()

# %% [markdown]
# ## Evaluate Both Models:MAE, MSE, RMSE, R²

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def evaluate_dt(model, name):
    y_pred = model.predict(X_test)
    print(f"{name} Evaluation:")
    print("MSE:", mean_squared_error(y_test, y_pred))
    print("MAE:", mean_absolute_error(y_test, y_pred))
    print("R2:", r2_score(y_test, y_pred))
    print("------")

evaluate_dt(dt1, "DT-1 (Fully Grown)")
evaluate_dt(dt2, "DT-2 (Pruned)")
# Out:
# DT-1 (Fully Grown) Evaluation:
# MSE: 1289.378787878788
# MAE: 28.848484848484848
# R2: -1.2969461209593582
# ------
# DT-2 (Pruned) Evaluation:
# MSE: 691.5658968669802
# MAE: 21.995023718009612
# R2: -0.23198056236808573
# ------

# %%
# Replace this with one-hot encoded and properly transformed input values
new_patient = pd.DataFrame({...}, index=[0])  # Fill with B002565 attributes
survival_months = dt2.predict(new_patient)  # or dt1
print("Predicted Survival Months:", survival_months[0])

# %% [markdown]
# # Summary
#
# - Gradient Boosting had the best R² score and lowest RMSE.
# - Feature importance analysis showed [insert top 3 features] as most influential.
# - Further improvements can include hyperparameter tuning and ensemble stacking.
